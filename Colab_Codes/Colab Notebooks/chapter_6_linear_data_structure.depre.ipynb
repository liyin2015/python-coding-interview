# %%
class Student:
    def __init__(self, name, grade, age):
        self.name = name
        self.grade = grade
        self.age = age
    def __repr__(self):
        return repr((self.name, self.grade, self.age))
     
    def __cmp__(self, other):
      return cmp((self.name, self.grade, self.age), (other.name, other.grade, other.age))
#     def __hash__(self):
#       return hash((self.name, self.grade, self.age))
    
#     def __lt__(self, other):
#         return cmp((self.name, self.grade, self.age), (other.name, other.grade, other.age)) < 0
#     def __gt__(self, other):
#         return cmp((self.name, self.grade, self.age), (other.name, other.grade, other.age)) > 0
#     def __eq__(self, other):
#         return cmp((self.name, self.grade, self.age), (other.name, other.grade, other.age)) == 0
#     def __le__(self, other):
#         return cmp((self.name, self.grade, self.age), (other.name, other.grade, other.age)) <= 0
#     def __ge__(self, other):
#         return cmp((self.name, self.grade, self.age), (other.name, other.grade, other.age)) >= 0
#     def __ne__(self, other):
#         return cmp((self.name, self.grade, self.age), (other.name, other.grade, other.age)) != 0

# %%
a =Student('John', 'A', 14)
print(type(('John', 'A', 14)), type(a))
print(hash(a))
print(a)
# Out:
# <class 'tuple'> <class '__main__.Student'>
# -9223363270192343580
# ('John', 'A', 14)

# %%
b = Student('Alex', 'A', 14)
print(a == b)
print(sorted([a,b]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-cbb523a685a6> in <module>()
#       1 b = Student('Alex', 'A', 14)
# ----> 2 print(a == b)
#       3 print(sorted([a,b]))
#
# <ipython-input-54-50417c1cbe83> in __eq__(self, other)
#      17         return cmp((self.name, self.grade, self.age), (other.name, other.grade, other.age)) > 0
#      18     def __eq__(self, other):
# ---> 19         return cmp((self.name, self.grade, self.age), (other.name, other.grade, other.age)) == 0
#      20     def __le__(self, other):
#      21         return cmp((self.name, self.grade, self.age), (other.name, other.grade, other.age)) <= 0
#
# NameError: name 'cmp' is not defined

# %%
key1 = hash(('John', 'A', 14))
key2 = hash(('John', 'A', 14))
print(key1, key2)
d = {('John', 'A', 14): 'A+'}
print(d[key1], d['John', 'A', 14])
# Out:
# 1266846023488010213 1266846023488010213
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-13671f2ed207> in <module>()
#       3 print(key1, key2)
#       4 d = {('John', 'A', 14): 'A+'}
# ----> 5 print(d[key1], d['John', 'A', 14])
#
# KeyError: 1266846023488010213

# %% [markdown]
# ## DFS tree search

# %% [markdown]
# ### A general purpose search

# %%
def dfs(t, s):
  '''implement the dfs recursive of tree'''
  print(s)
  for neighbor in t[s]:
    dfs(t, neighbor)
  return

# %%
t = {1: [2, 3], 2: [4, 5],
                    3: [], 4: [6], 5: [], 6: []}
dfs(t, 1)
# Out:
# 1
# 2
# 4
# 6
# 5
# 3
